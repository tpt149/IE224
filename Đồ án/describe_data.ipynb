# %%
import pandas as pd

# %%
data = pd.read_csv("final_data.csv")

# %%
data.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Body color            0
# Interior color        0
# Interior material     0
# Body                  0
# Doors                 0
# Seats                 0
# Fuel                  0
# Transmission          0
# Drive type            0
# Power                 0
# Engine capacity       0
# CO2 emissions         0
# Emission class        0
# Mileage               0
# First registration    0
# Battery type          0
# AC charging time      0
# Battery capacity      0
# Previous owners       0
# Warranty until        0
# Price                 0
# dtype: int64

# %%
for i in data.columns:
    print(f'{i}: ',data[i].unique())
# Out:
# Make:  ['Fiat' 'Ford' 'Volkswagen' 'Audi' 'BMW' 'MINI' 'Skoda' 'Mercedes-Benz'
#  'Seat' 'Opel' 'Hyundai' 'Volvo' 'Nissan' 'Renault' 'Kia' 'Citroen'
#  'Land Rover' 'Mazda' 'Peugeot' 'Mitsubishi' 'Cupra' 'Dacia' 'Jaguar' 'MG'
#  'Alfa Romeo' 'Toyota' 'DS Automobiles' 'Abarth' 'Porsche' 'Honda']
# Model:  ['500X' 'Focus' 'T-Roc' 'S5' '118' 'Cooper S Cabrio' 'Enyaq' 'Sprinter'
#  'Panda' 'Leon' 'Kodiaq' 'A 200' 'Astra' 'Ranger' 'Golf' 'Tucson' 'S60'
#  'Corsa' 'Micra' 'Koleos' 'Vito' 'T-Cross' 'Passat' 'C 180' "cee'd / Ceed"
#  'Golf Plus' 'C3 Aircross' 'E 400' 'Range Rover Velar' '500' 'C 220'
#  'Insignia' 'CLA 220 Shooting Brake' '6' '308' 'V60' 'CX-5' 'Cooper S'
#  'A 45 AMG' '120' 'X6' 'A4' 'X1' 'Superb' 'Puma' 'MX-30' 'Captur'
#  'Austral' 'MX-5' "pro_cee'd / ProCeed" 'Kamiq' 'Combo' 'One D Countryman'
#  'T6 California' 'Polo' 'Crafter' 'Caddy' 'CX-3' 'Ibiza' 'Crossland'
#  'Space Star' '440' 'A3' 'Staria' 'E 300' 'X4' 'Leaf' 'Q3' 'Clio' 'C3'
# ...

# %%
data['Price'].max()
# Out:
# 73299.0
